# %% [markdown]
# # Machine Learning
#
# Machine Learning is a program that analyses data and learns to predict the outcome.
#
# Data Types
#
# To analyze data, it is important to know what type of data we are dealing with.
#
# We can split the data types into three main categories:
#
# Numerical
# Categorical
# Ordinal
# Numerical data are numbers, and can be split into two numerical categories:
#
# Discrete Data
# - counted data that are limited to integers. Example: The number of cars passing by.
# Continuous Data
# - measured data that can be any number. Example: The price of an item, or the size of an item
# Categorical data are values that cannot be measured up against each other. Example: a color value, or any yes/no values.
#
# Ordinal data are like categorical data, but can be measured up against each other. Example: school grades where A is better than B and so on.
#
# By knowing the data type of your data source, you will be able to know what technique to use when analyzing them.

# %%
# Mean 

import numpy as np
from scipy import stats

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]
x = np.mean(speed)
y = np.median(speed)
z = stats.mode(speed)
print('x:', x)
print('y:', y)
print('z:', z)
# Out:
# x: 89.76923076923077
# y: 87.0
# z: ModeResult(mode=86, count=3)

# %%
""" Standard Deviation

It is a number that describes how spread out the values are.
A low standard deviation means that most of the numbers are close to the mean (average) value and vice versa. 
Standard Deviation: σ
"""

""" Variance
Variance is another number that indicates how spread out the values are.
Variance is square of standard Deviation
Variance : σ^2
"""
import numpy as np

speed = [86,87,88,86,87,85,86]
x = np.std(speed)
y = np.var(speed)
print('Standard Deviation', x)
print('Variance', y)
# Out:
# Standard Deviation 0.9035079029052513
# Variance 0.8163265306122449

# %%
""" Percentiles
Percentiles are used in statistics to give you a number that describes the value that a given percent of the values are lower than. 
"""
import numpy

ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]
x = numpy.percentile(ages, 75)
y = numpy.percentile(ages, 90)
print(x, y)
# Out:
# 43.0 61.0

# %%
# Data Distribution
# Big data Sets

import numpy as np
import matplotlib.pyplot as plt

x = np.random.uniform(0.0, 5.0, 100000)
#print(x)

plt.hist(x, 100)
plt.show()

# %%
# Normal Data Distribution

x = np.random.normal(5.0, 1.0, 100000) # (Mean, standard deviation, values)
plt.hist(x, 100)
plt.show()

# %%
# Scatter Plot

import matplotlib.pyplot as plt
ages = [5,7,8,7,2,17,2,9,4,11,12,9,6]
speeds = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(ages, speeds)
plt.xlabel('ages')
plt.ylabel('speeds')
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 1000)
y = numpy.random.normal(10.0, 2.0, 1000)

plt.scatter(x, y)
plt.show()

# We can see that the dots are concentrated around the value 5 on the x-axis, and 10 on the y-axis

# %%
# Regression
# The term regression is used when you try to find the relationship between variables.
# In Machine Learning, and in statistical modeling, that relationship is used to predict the outcome of future events.
""" Linear regression uses the relationship between the data-points to draw a straight line through all them.
This line can be used to predict future values. In Machine Learning, predicting the future is very important.
"""
from scipy import stats
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

res = stats.linregress(x, y)
# res will have slope, intercept, rvalue, pvalue, stderr
# print(res)

def myfunc(x):
    return res.slope * x + res.intercept

y_myfunc = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, y_myfunc)
plt.xlabel('ages')
plt.ylabel('speeds')
plt.show()

# %%
# the coefficient of correlation - is called r
# The r value ranges from -1 to 1, where 0 means no relationship, and 1 (and -1) means 100% related.
# How well the data fit in linear regression can be understood using r value

from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

""" slope, intercept, r, p, std_err = stats.linregress(x, y)
print(r) """

res = stats.linregress(x,y)
print(res.rvalue)

# Note: The result -0.76 shows that there is a relationship, not perfect, but it indicates that we could use linear regression in future predictions.
# Out:
# -0.758591524376155

# %%
# predicting the speed of a 10 years old car; Considering x = Age of Car, y = speed

def myfunc(x):
    return slope * x + intercept

speed  = myfunc(10)
print(speed)
# Out:
# 85.59308314937454

# %%
# Now the question is - Is the linear regression always the best method to use ?
# Example - where linear regression is not the best fit

# We check the rvalue first

import numpy
from scipy import stats

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

res = stats.linregress(x,y)
print(res.rvalue)
# Out:
# 0.013318141542974915

# %%
# So, rvalue = 0.013318141542974915, let's see how the plot is for this

from scipy import stats
import matplotlib.pyplot as plt

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

res = stats.linregress(x, y)

def myfunc(x):
    return res.slope * x + res.intercept

y_myfunc = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, y_myfunc)
plt.xlabel('ages')
plt.ylabel('speeds')
plt.show()

# We can see in plot tha values are scattered and simple straight line cannot define it

# %% [markdown]
# # Polynomial Regression
#
# If your data points clearly will not fit a linear regression (a straight line through all data points), it might be ideal for polynomial regression.
#
# Polynomial regression, like linear regression, uses the relationship between the variables x and y to find the best way to draw a line through the data points.
